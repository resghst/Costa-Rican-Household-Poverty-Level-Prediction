# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy.stats import norm
# %matplotlib inline

import os
# print(os.listdir('./data'))

tf_train = pd.read_csv('./data/train.csv')
tf_test = pd.read_csv('./data/test.csv')
tf_train.head()
tf_train.columns
# Out:
# Index(['Id', 'v2a1', 'hacdor', 'rooms', 'hacapo', 'v14a', 'refrig', 'v18q',
#        'v18q1', 'r4h1',
#        ...
#        'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin',
#        'SQBovercrowding', 'SQBdependency', 'SQBmeaned', 'agesq', 'Target'],
#       dtype='object', length=143)

# %%
def eda(data):
    bashline = 10*'-'
    # print(bashline,"Top-5- Record",bashline)
    # print(data.head(5))
    print(bashline,"Information",bashline)
    print(data.info())
    print(bashline,"Data Types",bashline)
    print(data.dtypes)
    print(bashline,"Missing value",bashline)
    print(data.isnull().sum())
    print(bashline,"Null value",bashline)
    print(data.isna().sum())
    print(bashline,"Shape of Data",bashline)
    print(data.shape)

def graph_insight(data):
    print(set(data.dtypes.tolist()))
    df_num = data.select_dtypes(include = ['float64', 'int64'])
    df_num.hist(figsize=(16, 16), bins=50, xlabelsize=8, ylabelsize=8);

# %%
tf_train = tf_train[tf_train['v2a1']!=0]
tf_train = tf_train[tf_train['v2a1']<=900000]
tf_train['v2a1'] = np.log(tf_train['v2a1'])
sns.distplot(tf_train['v2a1'], fit=norm)
# Out:
# C:\Users\HANK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(tf_train['rooms'], fit=norm)
# Out:
# C:\Users\HANK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tf_train['v18q1'] = tf_train['v18q1'].interpolate().fillna(0)
sns.distplot(tf_train['v18q1'].astype(int), fit=norm)
# Out:
# C:\Users\HANK\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# tf_train = tf_train[tf_train['r4h1']>=3]
tf_train = tf_train[tf_train['r4h1']<2]
tf_train['r4h1'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
tf_train = tf_train[tf_train['r4h2']>0]
tf_train = tf_train[tf_train['r4h2']<3]
tf_train['r4h2'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4h3']>0]
tf_train = tf_train[tf_train['r4h3']<3]
tf_train['r4h3'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4m1']>0]
tf_train = tf_train[tf_train['r4m1']!=2]
tf_train['r4m1'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
tf_train = tf_train[tf_train['r4m2']!=0]
tf_train = tf_train[tf_train['r4m2']!=3]
tf_train['r4m2'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4m3']!=0]
tf_train = tf_train[tf_train['r4m3']!=3]
tf_train['r4m3'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4t1']!=0]
tf_train = tf_train[tf_train['r4t1']!=2]
tf_train['r4t1'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4t2']!=0]
tf_train = tf_train[tf_train['r4t2']!=4]
tf_train['r4t2'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4t3']!=0]
tf_train['r4t3'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);
tf_train['r4t3'] = np.log(tf_train['r4t3'])
tf_train['r4t3'].hist(figsize=(8, 8), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# tf_train = tf_train[tf_train['r4t3']!=0]
tf_train['tamhog'].hist(figsize=(8, 8), xlabelsize=16, ylabelsize=16);

# %%
corrmat = tf_train.corr()
filename = 'correlation_matrix.png'
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
#saleprice correlation matrix
k = 15 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Target')['Target'].index
cm = np.corrcoef(tf_train[cols].values.T)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f',
                 annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)

# %%
cols = corrmat.nlargest(5, 'Target')['Target'].index
print(cols)
# Out:
# Index(['Target', 'v2a1', 'paredblolad', 'cielorazo', 'eviv3'], dtype='object')

# %%
sns.set()
# cols = ['Target', 'abastaguadentro', 'instlevel8', 'escolari']
sns.pairplot(tf_train[cols], size = 2.5)

# %%
# tf_train.rez_esc = tf_train.rez_esc.fillna(0)

data = tf_train.select_dtypes(include=[np.number]).interpolate().fillna(0)
testdata = tf_test.select_dtypes(include=[np.number]).interpolate().fillna(0)
y = tf_train.Target
X = data.drop(['Target'], axis=1)
# eda(tf_test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=55, test_size=.2)

from sklearn.cluster import KMeans
kmeans = KMeans().fit(X_train,y_train)
predictions = kmeans.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \t', mean_squared_error(y_test, predictions))
print(tf_test.columns)
feats = tf_test.select_dtypes(include=[np.number]).interpolate().fillna(0)
print(feats.columns)
# eda(feats)
# print(feats.v2a1)
finialpredictions = kmeans.predict(feats)
# Out:
# RMSE is: 	 7.432291666666667
# Index(['Id', 'v2a1', 'hacdor', 'rooms', 'hacapo', 'v14a', 'refrig', 'v18q',
#        'v18q1', 'r4h1',
#        ...
#        'age', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe',
#        'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned',
#        'agesq'],
#       dtype='object', length=142)
# Index(['v2a1', 'hacdor', 'rooms', 'hacapo', 'v14a', 'refrig', 'v18q', 'v18q1',
#        'r4h1', 'r4h2',
#        ...
#        'age', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe',
#        'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned',
#        'agesq'],
#       dtype='object', length=137)

# %%
print(tf_test)
print(len(finialpredictions))
submission = pd.DataFrame()
submission['Id'] = tf_test.Id
submission['SalePrice'] = finialpredictions
submission.to_csv('output.csv', index=False)
# Out:
#                  Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  \
# 0      ID_2f6873615       NaN       0      5       0     1       1     0
# 1      ID_1c78846d2       NaN       0      5       0     1       1     0
# 2      ID_e5442cf6a       NaN       0      5       0     1       1     0
# 3      ID_a8db26a79       NaN       0     14       0     1       1     1
# 4      ID_a62966799  175000.0       0      4       0     1       1     1
# 5      ID_e77d38d45  400000.0       0      3       0     1       1     1
# 6      ID_3c5f4bd51  400000.0       0      3       0     1       1     1
# 7      ID_a849c29bd  300000.0       0      6       0     1       1     1
#
#        v18q1  r4h1  ...    age  SQBescolari  SQBage  SQBhogar_total  \
# 0        NaN     1  ...      4            0      16               9
# 1        NaN     1  ...     41          256    1681               9
# 2        NaN     1  ...     41          289    1681               9
# 3        1.0     0  ...     59          256    3481               1
# 4        1.0     0  ...     18          121     324               1
# 5        1.0     0  ...     38          256    1444               4
# 6        1.0     0  ...     42          121    1764               4
# 7        1.0     0  ...     21          196     441               4
# 8        1.0     0  ...     22          196     484               4
# 9        NaN     0  ...     70          100    4900               1
# 10       NaN     0  ...     18          100     324               9
# 11       NaN     0  ...     55           81    3025               9
# 12       NaN     0  ...     53          225    2809               9
# 13       NaN     0  ...     51          100    2601              36
# 14       NaN     0  ...     52          121    2704              36
# 15       NaN     0  ...     15           81     225              36
# 16       NaN     0  ...     22           81     484              36
# 17       NaN     0  ...     21          144     441              36
# 18       NaN     0  ...     17          100     289              36
# 19       NaN     0  ...     27           81     729               9
# 20       NaN     0  ...     45           81    2025               9
# 21       NaN     0  ...     32           36    1024               9
# 22       NaN     0  ...     25          169     625               4
# 23       NaN     0  ...     66           81    4356               4
# 24       2.0     0  ...      3            0       9              16
# 25       2.0     0  ...     33          121    1089              16
# 26       2.0     0  ...     30          121     900              16
# 27       2.0     0  ...      6            0      36              16
# 28       1.0     0  ...     27           49     729               9
# 29       1.0     0  ...     78           64    6084               9
# ...      ...   ...  ...    ...          ...     ...             ...
# 23826    NaN     1  ...      6            0      36               4
# 23827    NaN     0  ...     36           25    1296               9
# 23828    NaN     0  ...     69            0    4761               9
# 23829    NaN     0  ...     62            0    3844               9
# 23830    NaN     0  ...     18           64     324               4
# 23831    NaN     0  ...     25           81     625               4
# 23832    NaN     0  ...     51           25    2601               9
# 23833    NaN     0  ...     53           36    2809               9
# 23834    NaN     0  ...     16           64     256               9
# 23835    NaN     1  ...      5            0      25               4
# 23836    NaN     1  ...     68            9    4624               4
# 23837    NaN     1  ...     15           64     225              36
# 23838    NaN     1  ...      1            0       1              36
# 23839    NaN     1  ...      9            4      81              36
# 23840    NaN     1  ...     39           36    1521              36
# 23841    NaN     1  ...     42           16    1764              36
# 23842    NaN     1  ...     14           49     196              36
# 23843    NaN     0  ...     47            0    2209               9
# 23844    NaN     0  ...     15           64     225               9
# 23845    NaN     0  ...     33          121    1089               9
# 23846    NaN     0  ...     24           25     576              36
# 23847    NaN     0  ...     57           25    3249              36
# 23848    NaN     0  ...     18            0     324              36
# 23849    NaN     0  ...     47           25    2209              36
# 23850    NaN     0  ...     27           64     729              36
# 23851    NaN     0  ...     10            9     100              36
# 23852    NaN     0  ...     54           36    2916              16
# 23853    NaN     0  ...     12           16     144              16
# 23854    NaN     0  ...     12           25     144              16
# 23855    NaN     0  ...     51           36    2601              16
#
#        SQBedjefe  SQBhogar_nin  SQBovercrowding  SQBdependency   SQBmeaned  \
# 0              0             1         2.250000           0.25  272.250000
# 1              0             1         2.250000           0.25  272.250000
# 2              0             1         2.250000           0.25  272.250000
# 3            256             0         1.000000           0.00  256.000000
# 4              0             1         0.250000          64.00         NaN
# 5              0             0         1.000000           0.00  182.250000
# 6              0             0         1.000000           0.00  182.250000
# 7              0             0         0.250000           0.00  196.000000
# 8              0             0         0.250000           0.00  196.000000
